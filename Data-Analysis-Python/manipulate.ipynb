# %%
import pandas as pd

sales = pd.read_csv('sales.csv')

# Print the first 5 rows of the sales DataFrame

print(sales.head(5))

# Print the last 5 rows of the sales DataFrame

print(sales.tail(5))
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# ...

# %%
sales.describe
# Out:
# <bound method NDFrame.describe of     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
# ...

# %%
# Handling missing data

print(sales.isnull())
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0          False      False     False       False        False    False
# 1          False      False     False       False        False    False
# 2          False      False     False       False        False    False
# 3          False      False     False       False        False    False
# 4          False      False     False       False        False    False
# 5          False      False     False       False        False    False
# 6          False      False     False       False        False    False
# 7          False      False     False       False        False    False
# 8          False      False     False       False        False    False
# 9          False      False     False       False        False    False
# 10         False      False     False       False        False    False
# 11         False      False     False       False        False    False
#
# ...

# %%
sales.dtypes
# Out:
# month_number    int64
# facecream       int64
# facewash        int64
# toothpaste      int64
# bathingsoap     int64
# shampoo         int64
# moisturizer     int64
# total_units     int64
# total_profit    int64
# dtype: object

# %%
sales.isnull().sum()
# Out:
# month_number    0
# facecream       0
# facewash        0
# toothpaste      0
# bathingsoap     0
# shampoo         0
# moisturizer     0
# total_units     0
# total_profit    0
# dtype: int64

# %%
sales['new_total_profit'] = sales['total_profit'].fillna(sales['total_profit'].mean()).astype(float)
sales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
sales.rename(columns={'total_profit':'total_profit($)'}, inplace=True)
sales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
sales['doller_cost'] = sales['total_profit($)'].apply(lambda x: x*81)
sales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
# Join two dataframes

d1 = {'customer_id':pd.Series([1,2,3,4,5,6]),   'customer_name':pd.Series(['Andrew','Alex','John','Jane','Smith','Ben'])}

d2 = {'customer_id':pd.Series([1,2,3,4,5,6]),   'customer_name':pd.Series(['Andrew','Alex','John','Jane','Smith','Ben'])}

pd.merge(d1,d2,on='customer_id',how='inner')
